# %% [markdown]
# <a href="https://colab.research.google.com/github/muammarzainza2000/data-science-2026/blob/main/Pertemuan1__Muammar_Zain_Z_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Muammar Zain Z.A <br>
# NIM: 240401010304 <br>
# Kelas: IF 401 <br>

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
status = "Mahasiswa Informatika"
tahun = 2025

print(f"Halo, {status} angkatan {tahun}!")
# Out:
# Halo, Mahasiswa Informatika angkatan 2025!

# %%
tools = ["Python", "Google Colab", "Jupiter Notebook", "GitHub"]

for i, tool in enumerate(tools, 1):
  print(f"{i}.{tool}")
# Out:
# 1.Python
# 2.Google Colab
# 3.Jupiter Notebook
# 4.GitHub

# %%
def perkenalan(nama, jurusan, angkatan):
  return f"{nama} | {jurusan} | {angkatan}"
print(perkenalan("Muammar Zain Z.A", "Informatika", 2025))
# Out:
# Muammar Zain Z.A | Informatika | 2025

# %% [markdown]
# ### Kesimpulan:
# Pada pertemuan ini mempelajari mengenai logika dasar pemrograman dan sintaks dasar python. Disini membahas tentang cara membuat output, membuat variabel, membuat list / array dan membuat fungsi.
